# %% [markdown]
# # PROJECT 2

# %% [markdown]
# ## Table of contents
# <a id='table_of_contents'></a>
#
# 0. [Import libraries](#import_libraries)
# 1. [Import data](#import_data)
# 2. [Data exploration](#data_exploration)
# 3. [Data cleaning](#data_cleaning)
# 4. [Data preparation](#data_preparation)
# 5. [Benchmark model](#Benchmark_model)
#     5.1. [Train-test split](#Train-test_split)
#     5.2. [Fit a model to the data](#Fit_a_model_to_the_data)
#     5.3. [Model evaluation](#Model_evaluation)
# 7. [Feature engineering](#Feature_engineering)
# 8. [Model training](#Model_training)
#     7.1. [Decision Tree](#Decision_tree)
#     7.2. [KNN](#KNN)
#     7.3. [Comparing algorithm performances](#Comparing_algorithm_performances)
# 9. [Tuning](#Tuning)

# %% [markdown]
# ### 0.Import libraries  <a id='import_libraries'></a>
#
#
#
# [Back_to_top](#table_of_contents)

# %%
import pandas as pd 
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
import scipy
import sklearn

# %% [markdown]
# ### 1.Import Data <a id='import_data'></a>
# [Back_to_top](#table_of_contents)

# %%
hcc_data = pd.read_csv("hcc_dataset.csv")

# %%
pd.set_option('display.max_columns',None)

# %%
print(hcc_data.shape)
hcc_data.head()
# Out:
# (165, 50)
#    Gender Symptoms Alcohol HBsAg HBeAg HBcAb HCVAb Cirrhosis Endemic Smoking  \
# 0    Male       No     Yes    No    No    No    No       Yes      No     Yes
# 1  Female        ?      No    No    No    No   Yes       Yes       ?       ?
# 2    Male       No     Yes   Yes    No   Yes    No       Yes      No     Yes
# 3    Male      Yes     Yes    No    No    No    No       Yes      No     Yes
# 4    Male      Yes     Yes   Yes    No   Yes    No       Yes      No     Yes
#
#   Diabetes Obesity Hemochro  AHT  CRI HIV NASH Varices Spleno  PHT PVT  \
# 0      Yes       ?      Yes   No   No  No   No     Yes     No   No  No
# 1      Yes      No       No  Yes   No  No   No     Yes     No   No  No
# 2       No      No       No  Yes  Yes  No   No      No     No  Yes  No
# 3      Yes      No       No  Yes   No  No   No      No     No   No  No
# 4       No      No       No  Yes  Yes  No   No      No     No   No  No
#
#   Metastasis Hallmark  Age Grams_day Packs_year          PS Encephalopathy  \
# 0         No      Yes   67       137         15      Active            NaN
# 1         No      Yes   62         0          ?      Active            NaN
# 2        Yes      Yes   78        50         50  Ambulatory            NaN
# 3        Yes      Yes   77        40         30      Active            NaN
# 4         No      Yes   76       100         30      Active            NaN
#
#   Ascites   INR   AFP Hemoglobin    MCV Leucocytes Platelets  Albumin  \
# 0     NaN  1.53    95       13.7  106.6        4.9        99      3.4
# 1     NaN     ?     ?          ?      ?          ?         ?        ?
# 2    Mild  0.96   5.8        8.9   79.8        8.4       472      3.3
# 3     NaN  0.95  2440       13.4   97.1          9       279      3.7
# 4     NaN  0.94    49       14.3   95.1        6.4       199      4.1
#
#   Total_Bil  ALT  AST  GGT  ALP   TP Creatinine Nodules Major_Dim Dir_Bil  \
# 0       2.1   34   41  183  150  7.1        0.7       1       3.5     0.5
# 1         ?    ?    ?    ?    ?    ?          ?       1       1.8       ?
# 2       0.4   58   68  202  109    7        2.1       5        13     0.1
# 3       0.4   16   64   94  174  8.1       1.11       2      15.7     0.2
# 4       0.7  147  306  173  109  6.9        1.8       1         9       ?
#
#   Iron Sat Ferritin  Class
# 0    ?   ?        ?  Lives
# 1    ?   ?        ?  Lives
# 2   28   6       16  Lives
# 3    ?   ?        ?   Dies
# 4   59  15       22  Lives

# %% [markdown]
# ### 2.Data exploration  <a id='data_exploration'></a>
#
# [Back_to_top](#table_of_contents)

# %%
hcc_data.columns
# Out:
# Index(['Gender', 'Symptoms', 'Alcohol', 'HBsAg', 'HBeAg', 'HBcAb', 'HCVAb',
#        'Cirrhosis', 'Endemic', 'Smoking', 'Diabetes', 'Obesity', 'Hemochro',
#        'AHT', 'CRI', 'HIV', 'NASH', 'Varices', 'Spleno', 'PHT', 'PVT',
#        'Metastasis', 'Hallmark', 'Age', 'Grams_day', 'Packs_year', 'PS',
#        'Encephalopathy', 'Ascites', 'INR', 'AFP', 'Hemoglobin', 'MCV',
#        'Leucocytes', 'Platelets', ' Albumin', 'Total_Bil', 'ALT', 'AST', 'GGT',
#        'ALP', 'TP', 'Creatinine', 'Nodules', 'Major_Dim', 'Dir_Bil', 'Iron',
#        'Sat', 'Ferritin', 'Class'],
#       dtype='object')

# %%
hcc_data.dtypes
# Out:
# Gender            object
# Symptoms          object
# Alcohol           object
# HBsAg             object
# HBeAg             object
# HBcAb             object
# HCVAb             object
# Cirrhosis         object
# Endemic           object
# Smoking           object
# Diabetes          object
# Obesity           object
# Hemochro          object
# AHT               object
# CRI               object
# HIV               object
# NASH              object
# Varices           object
# Spleno            object
# PHT               object
# PVT               object
# Metastasis        object
# Hallmark          object
# Age                int64
# Grams_day         object
# Packs_year        object
# PS                object
# Encephalopathy    object
# Ascites           object
# INR               object
# AFP               object
# Hemoglobin        object
# MCV               object
# Leucocytes        object
# Platelets         object
#  Albumin          object
# Total_Bil         object
# ALT               object
# AST               object
# GGT               object
# ALP               object
# TP                object
# Creatinine        object
# Nodules           object
# Major_Dim         object
# Dir_Bil           object
# Iron              object
# Sat               object
# Ferritin          object
# Class             object
# dtype: object

# %%
numerical_columns = hcc_data[['Age','Grams_day', 'Packs_year','INR', 'AFP', 'Hemoglobin', 'MCV',
       'Leucocytes', 'Platelets', ' Albumin', 'Total_Bil', 'ALT', 'AST', 'GGT',
       'ALP', 'TP', 'Creatinine', 'Nodules', 'Major_Dim', 'Dir_Bil', 'Iron',
       'Sat', 'Ferritin']]
numerical_columns = numerical_columns.astype(float)

# %%
hcc_data.dtypes
# Out:
# Gender             object
# Symptoms           object
# Alcohol            object
# HBsAg              object
# HBeAg              object
# HBcAb              object
# HCVAb              object
# Cirrhosis          object
# Endemic            object
# Smoking            object
# Diabetes           object
# Obesity            object
# Hemochro           object
# AHT                object
# CRI                object
# HIV                object
# NASH               object
# Varices            object
# Spleno             object
# PHT                object
# PVT                object
# Metastasis         object
# Hallmark           object
# Age                 int64
# Grams_day         float64
# Packs_year        float64
# PS                 object
# Encephalopathy     object
# Ascites            object
# INR               float64
# AFP               float64
# Hemoglobin        float64
# MCV               float64
# Leucocytes        float64
# Platelets         float64
#  Albumin          float64
# Total_Bil         float64
# ALT               float64
# AST               float64
# GGT               float64
# ALP               float64
# TP                float64
# Creatinine        float64
# Nodules           float64
# Major_Dim         float64
# Dir_Bil           float64
# Iron              float64
# Sat               float64
# Ferritin          float64
# Class              object
# dtype: object

# %%
hcc_data.hist(figsize=(20,15),bins=60)
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Grams_day'}>,
#         <Axes: title={'center': 'Packs_year'}>,
#         <Axes: title={'center': 'INR'}>, <Axes: title={'center': 'AFP'}>],
#        [<Axes: title={'center': 'Hemoglobin'}>,
#         <Axes: title={'center': 'MCV'}>,
#         <Axes: title={'center': 'Leucocytes'}>,
#         <Axes: title={'center': 'Platelets'}>,
#         <Axes: title={'center': ' Albumin'}>],
#        [<Axes: title={'center': 'Total_Bil'}>,
#         <Axes: title={'center': 'ALT'}>, <Axes: title={'center': 'AST'}>,
#         <Axes: title={'center': 'GGT'}>, <Axes: title={'center': 'ALP'}>],
#        [<Axes: title={'center': 'TP'}>,
#         <Axes: title={'center': 'Creatinine'}>,
#         <Axes: title={'center': 'Nodules'}>,
#         <Axes: title={'center': 'Major_Dim'}>,
#         <Axes: title={'center': 'Dir_Bil'}>],
#        [<Axes: title={'center': 'Iron'}>,
#         <Axes: title={'center': 'Sat'}>,
#         <Axes: title={'center': 'Ferritin'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
hcc_data.reset_index().plot(kind='scatter',y='Grams_day',x='index',figsize=(10,5))
# Out:
# <Axes: xlabel='index', ylabel='Grams_day'>

# %%
sns.boxplot(x=hcc_data['Grams_day'])
# Out:
# <Axes: xlabel='Grams_day'>

# %%
hcc_data.reset_index().plot(kind='scatter',y='Packs_year',x='index',figsize=(10,5))
# Out:
# <Axes: xlabel='index', ylabel='Packs_year'>

# %%
hcc_data[hcc_data['Packs_year']>100].shape
# Out:
# (1, 50)

# %%
hcc_data.reset_index().plot(kind='scatter',y='INR',x='index',figsize=(10,5))
# Out:
# <Axes: xlabel='index', ylabel='INR'>

# %%
hcc_data[hcc_data['Packs_year']>2.5].shape
# Out:
# (49, 50)

# %%
hcc_data.reset_index().plot(kind='scatter',y='AFP',x='index',figsize=(10,5))
# Out:
# <Axes: xlabel='index', ylabel='AFP'>

# %%
hcc_data[hcc_data['Packs_year']>500].shape
# Out:
# (1, 50)

# %%
hcc_data.reset_index().plot(kind='scatter',y='Hemoglobin',x='index',figsize=(10,5))
# Out:
# <Axes: xlabel='index', ylabel='Hemoglobin'>

# %%
hcc_data['Hemoglobin'].mean()
# Out:
# 12.87901234567901

# %%
hcc_data[hcc_data['Hemoglobin']<10].shape
# Out:
# (15, 50)

# %%
hcc_data[hcc_data['Hemoglobin']>17.2].shape
# Out:
# (1, 50)

# %%
hcc_data.reset_index().plot(kind='scatter',y='MCV',x='index',figsize=(10,5))
# Out:
# <Axes: xlabel='index', ylabel='MCV'>

# %%
hcc_data[hcc_data['MCV']>111].shape
# Out:
# (5, 50)

# %%
hcc_data[hcc_data['MCV']<71].shape
# Out:
# (2, 50)

# %%
hcc_data.reset_index().plot(kind='scatter',y='Leucocytes',x='index',figsize=(10,5))
# Out:
# <Axes: xlabel='index', ylabel='Leucocytes'>

# %%
hcc_data[hcc_data['Leucocytes']>11000].shape
# Out:
# (1, 50)

# %%
hcc_data['Leucocytes'].describe()
# Out:
# count      162.000000
# mean      1473.961549
# std       2909.106006
# min          2.200000
# 25%          5.100000
# 50%          7.200000
# 75%         19.525000
# max      13000.000000
# Name: Leucocytes, dtype: float64

# %%
hcc_data[hcc_data['Leucocytes']<200].shape
# Out:
# (124, 50)

# %%
hcc_data.reset_index().plot(kind='scatter',y='Platelets',x='index',figsize=(10,5))
# Out:
# <Axes: xlabel='index', ylabel='Platelets'>

# %%
hcc_data['Platelets'].describe()
# Out:
# count       162.000000
# mean     113206.442654
# std      107118.632481
# min           1.710000
# 25%         255.750000
# 50%       93000.000000
# 75%      171500.000000
# max      459000.000000
# Name: Platelets, dtype: float64

# %%
hcc_data[hcc_data['Platelets']<50000].shape
# Out:
# (50, 50)

# %%
hcc_data.reset_index().plot(kind='scatter',y=' Albumin',x='index',figsize=(10,5))
# Out:
# <Axes: xlabel='index', ylabel=' Albumin'>

# %%
hcc_data[hcc_data[' Albumin']<2.0].shape
# Out:
# (2, 50)

# %%
hcc_data.reset_index().plot(kind='scatter',y='Total_Bil',x='index',figsize=(10,5))
# Out:
# <Axes: xlabel='index', ylabel='Total_Bil'>

# %%
hcc_data[hcc_data['Total_Bil']>20].shape
# Out:
# (4, 50)

# %%
hcc_data.reset_index().plot(kind='scatter',y='ALT',x='index',figsize=(10,5))
# Out:
# <Axes: xlabel='index', ylabel='ALT'>

# %%
hcc_data['ALT'].describe()
# Out:
# count    161.000000
# mean      67.093168
# std       57.539747
# min       11.000000
# 25%       31.000000
# 50%       50.000000
# 75%       78.000000
# max      420.000000
# Name: ALT, dtype: float64

# %%
hcc_data[hcc_data['ALT']>300].shape
# Out:
# (1, 50)

# %%
hcc_data.reset_index().plot(kind='scatter',y='AST',x='index',figsize=(10,5))
# Out:
# <Axes: xlabel='index', ylabel='AST'>

# %%
hcc_data['AST'].describe()
# Out:
# count    162.000000
# mean      96.382716
# std       87.484241
# min       17.000000
# 25%       46.250000
# 50%       71.000000
# 75%      110.250000
# max      553.000000
# Name: AST, dtype: float64

# %%
hcc_data[hcc_data['AST']>400].shape
# Out:
# (3, 50)

# %%
hcc_data[hcc_data['AST']<25].shape
# Out:
# (5, 50)

# %%
hcc_data.reset_index().plot(kind='scatter',y='GGT',x='index',figsize=(10,5))
# Out:
# <Axes: xlabel='index', ylabel='GGT'>

# %%
hcc_data['GGT'].describe()
# Out:
# count     162.000000
# mean      268.026543
# std       258.750319
# min        23.000000
# 25%        91.250000
# 50%       179.500000
# 75%       345.250000
# max      1575.000000
# Name: GGT, dtype: float64

# %%
hcc_data[hcc_data['GGT']>=1000].shape
# Out:
# (2, 50)

# %%
hcc_data.reset_index().plot(kind='scatter',y='ALP',x='index',figsize=(10,5))
# Out:
# <Axes: xlabel='index', ylabel='ALP'>

# %%
hcc_data['ALP'].describe()
# Out:
# count    162.000000
# mean     212.211605
# std      167.943548
# min        1.280000
# 25%      108.250000
# 50%      162.000000
# 75%      261.500000
# max      980.000000
# Name: ALP, dtype: float64

# %%
hcc_data[hcc_data['ALP']<30].shape
# Out:
# (1, 50)

# %%
hcc_data[hcc_data['ALP']>800].shape
# Out:
# (3, 50)

# %%
hcc_data.reset_index().plot(kind='scatter',y='Creatinine',x='index',figsize=(10,5))
# Out:
# <Axes: xlabel='index', ylabel='Creatinine'>

# %%
hcc_data['Creatinine'].describe()
# Out:
# count    158.000000
# mean       1.127089
# std        0.955856
# min        0.200000
# 25%        0.700000
# 50%        0.850000
# 75%        1.100000
# max        7.600000
# Name: Creatinine, dtype: float64

# %%
hcc_data[hcc_data['Creatinine']>4].shape
# Out:
# (4, 50)

# %%
hcc_data.reset_index().plot(kind='scatter',y='TP',x='index',figsize=(10,5))
# Out:
# <Axes: xlabel='index', ylabel='TP'>

# %%
hcc_data['TP'].describe()
# Out:
# count    154.000000
# mean       8.961039
# std       11.728739
# min        3.900000
# 25%        6.300000
# 50%        7.050000
# 75%        7.575000
# max      102.000000
# Name: TP, dtype: float64

# %%
hcc_data[hcc_data['TP']>11].shape
# Out:
# (6, 50)

# %%
hcc_data.reset_index().plot(kind='scatter',y='Major_Dim',x='index',figsize=(10,5))
# Out:
# <Axes: xlabel='index', ylabel='Major_Dim'>

# %%
hcc_data[hcc_data['Major_Dim']>20].shape
# Out:
# (1, 50)

# %%
hcc_data.reset_index().plot(kind='scatter',y='Dir_Bil',x='index',figsize=(10,5))
# Out:
# <Axes: xlabel='index', ylabel='Dir_Bil'>

# %%
hcc_data[hcc_data['Dir_Bil']>7].shape
# Out:
# (6, 50)

# %%
hcc_data.reset_index().plot(kind='scatter',y='Iron',x='index',figsize=(10,5))
# Out:
# <Axes: xlabel='index', ylabel='Iron'>

# %%
hcc_data[hcc_data['Iron']<10].shape
# Out:
# (2, 50)

# %%
hcc_data[hcc_data['Iron']>200].shape
# Out:
# (1, 50)

# %%
hcc_data.reset_index().plot(kind='scatter',y='Sat',x='index',figsize=(10,5))
# Out:
# <Axes: xlabel='index', ylabel='Sat'>

# %%
hcc_data[hcc_data['Sat']>90].shape
# Out:
# (6, 50)

# %%
hcc_data.reset_index().plot(kind='scatter',y='Ferritin',x='index',figsize=(10,5))
# Out:
# <Axes: xlabel='index', ylabel='Ferritin'>

# %%
hcc_data['Ferritin'].describe()
# Out:
# count      85.000000
# mean      438.997647
# std       457.114454
# min         0.000000
# 25%        84.000000
# 50%       295.000000
# 75%       706.000000
# max      2230.000000
# Name: Ferritin, dtype: float64

# %%
hcc_data[hcc_data['Ferritin']>1000].shape
# Out:
# (7, 50)

# %% [markdown]
# ### 3.Data cleaning  <a id='data_cleaning'></a>
#
# [Back_to_top](#table_of_contents)

# %%
median_value = hcc_data[hcc_data['Grams_day'] <300]['Grams_day'].median()
hcc_data.loc[hcc_data['Grams_day'] >= 300, 'Grams_day'] = median_value

# %%
median_value = hcc_data[hcc_data['Packs_year'] < 100]['Packs_year'].median()
hcc_data.loc[hcc_data['Packs_year'] >= 100, 'Packs_year'] = median_value

# %%
median_value = hcc_data[hcc_data['INR'] < 2.5]['INR'].median()
hcc_data.loc[hcc_data['INR'] >= 2.5, 'INR'] = median_value

# %%
median_value = hcc_data[hcc_data['AFP'] < 125000]['AFP'].median()
hcc_data.loc[hcc_data['AFP'] >= 125000, 'AFP'] = median_value

# %%
hcc_data['AFP'].hist()
# Out:
# <Axes: >

# %%
median_value = hcc_data[hcc_data['Hemoglobin'] > 6]['Hemoglobin'].median()
hcc_data.loc[hcc_data['Hemoglobin'] <= 6, 'Hemoglobin'] = median_value

# %%
median_value = hcc_data[(hcc_data['MCV'] > 71) & (hcc_data['MCV'] < 111)]['MCV'].median()
hcc_data.loc[(hcc_data['MCV'] <= 71 )|(hcc_data['MCV'] >=111 ), 'MCV'] = median_value

# %%
median_value = hcc_data[hcc_data['Total_Bil'] < 20]['Total_Bil'].median()
hcc_data.loc[hcc_data['Total_Bil'] >= 20, 'Total_Bil'] = median_value

# %%
median_value = hcc_data[hcc_data['AST'] < 500]['AST'].median()
hcc_data.loc[hcc_data['AST'] >= 500, 'AST'] = median_value

# %%
median_value = hcc_data[hcc_data['GGT'] < 1000]['GGT'].median()
hcc_data.loc[hcc_data['GGT'] >= 1000, 'GGT'] = median_value

# %%
median_value = hcc_data[(hcc_data['ALP'] > 30) & (hcc_data['ALP'] < 800)]['ALP'].median()
hcc_data.loc[(hcc_data['ALP'] <= 30 )|(hcc_data['ALP'] >=800 ), 'ALP'] = median_value

# %%
median_value = hcc_data[hcc_data['Creatinine'] < 4]['Creatinine'].median()
hcc_data.loc[hcc_data['Creatinine'] >= 4, 'Creatinine'] = median_value

# %%
median_value = hcc_data[hcc_data['TP'] < 20]['TP'].median()
hcc_data.loc[hcc_data['TP'] >= 20, 'TP'] = median_value

# %%
median_value = hcc_data[hcc_data['Major_Dim'] < 20]['Major_Dim'].median()
hcc_data.loc[hcc_data['Major_Dim'] >= 20, 'Major_Dim'] = median_value

# %%
median_value = hcc_data[hcc_data['Dir_Bil'] < 18]['Dir_Bil'].median()
hcc_data.loc[hcc_data['Dir_Bil'] >= 18, 'Dir_Bil'] = median_value

# %%
median_value = hcc_data[(hcc_data['Iron'] > 10) & (hcc_data['Iron'] < 200)]['Iron'].median()
hcc_data.loc[(hcc_data['Iron'] <= 10 )|(hcc_data['Iron'] >=200 ), 'Iron'] = median_value

# %%
median_value = hcc_data[(hcc_data['Ferritin'] > 10) & (hcc_data['Ferritin'] < 1250)]['Ferritin'].median()
hcc_data.loc[(hcc_data['Ferritin'] <= 10 )|(hcc_data['Ferritin'] >=1250 ), 'Ferritin'] = median_value

# %%
hcc_data.hist(figsize=(20,13))
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Grams_day'}>,
#         <Axes: title={'center': 'Packs_year'}>,
#         <Axes: title={'center': 'INR'}>, <Axes: title={'center': 'AFP'}>],
#        [<Axes: title={'center': 'Hemoglobin'}>,
#         <Axes: title={'center': 'MCV'}>,
#         <Axes: title={'center': 'Leucocytes'}>,
#         <Axes: title={'center': 'Platelets'}>,
#         <Axes: title={'center': ' Albumin'}>],
#        [<Axes: title={'center': 'Total_Bil'}>,
#         <Axes: title={'center': 'ALT'}>, <Axes: title={'center': 'AST'}>,
#         <Axes: title={'center': 'GGT'}>, <Axes: title={'center': 'ALP'}>],
#        [<Axes: title={'center': 'TP'}>,
#         <Axes: title={'center': 'Creatinine'}>,
#         <Axes: title={'center': 'Nodules'}>,
#         <Axes: title={'center': 'Major_Dim'}>,
#         <Axes: title={'center': 'Dir_Bil'}>],
#        [<Axes: title={'center': 'Iron'}>,
#         <Axes: title={'center': 'Sat'}>,
#         <Axes: title={'center': 'Ferritin'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
hcc_data.replace('?', np.nan, inplace=True)

# %%
mask = ((hcc_data['Class'] == 'Lives') | (hcc_data['Class'] == 'Dies'))
hcc_data.loc[mask,'Encephalopathy'] = hcc_data.loc[mask,'Encephalopathy'].fillna('Not Applicable')
hcc_data.loc[mask,'Ascites'] = hcc_data.loc[mask,'Ascites'].fillna('Not Applicable')

# %%
hcc_data.isna().sum()
# Out:
# Gender             0
# Symptoms          18
# Alcohol            0
# HBsAg             17
# HBeAg             39
# HBcAb             24
# HCVAb              9
# Cirrhosis          0
# Endemic           39
# Smoking           41
# Diabetes           3
# Obesity           10
# Hemochro          23
# AHT                3
# CRI                2
# HIV               14
# NASH              22
# Varices           52
# Spleno            15
# PHT               11
# PVT                3
# Metastasis         4
# Hallmark           2
# Age                0
# Grams_day         48
# Packs_year        53
# PS                 0
# Encephalopathy     0
# Ascites            0
# INR                4
# AFP                8
# Hemoglobin         3
# MCV                3
# Leucocytes         3
# Platelets          3
#  Albumin           6
# Total_Bil          5
# ALT                4
# AST                3
# GGT                3
# ALP                3
# TP                11
# Creatinine         7
# Nodules            2
# Major_Dim         20
# Dir_Bil           44
# Iron              79
# Sat               80
# Ferritin          80
# Class              0
# dtype: int64

# %%
def impute_missing_data(data):
    for column in data.columns:
        if data[column].dtype == 'object':  # Para dados categóricos
            # Preencher com a moda
            mode_value = data[column].mode()[0]
            data[column].fillna(mode_value,inplace=True)
        else:  # Para dados numéricos
            # Preencher com a mediana
            median_value = data[column].median()
            data[column].fillna(median_value,inplace=True)

# Aplicar a função ao dataset
impute_missing_data(hcc_data)
# Out:
# C:\Users\leono\AppData\Local\Temp\ipykernel_17268\992650362.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(mode_value,inplace=True)
# C:\Users\leono\AppData\Local\Temp\ipykernel_17268\992650362.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(median_value,inplace=True)
# C:\Users\leono\AppData\Local\Temp\ipykernel_17268\992650362.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(median_value,inplace=True)
# C:\Users\leono\AppData\Local\Temp\ipykernel_17268\992650362.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(median_value,inplace=True)
# C:\Users\leono\AppData\Local\Temp\ipykernel_17268\992650362.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(mode_value,inplace=True)
# C:\Users\leono\AppData\Local\Temp\ipykernel_17268\992650362.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(median_value,inplace=True)
# C:\Users\leono\AppData\Local\Temp\ipykernel_17268\992650362.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(median_value,inplace=True)
# C:\Users\leono\AppData\Local\Temp\ipykernel_17268\992650362.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(median_value,inplace=True)
# C:\Users\leono\AppData\Local\Temp\ipykernel_17268\992650362.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(median_value,inplace=True)
# C:\Users\leono\AppData\Local\Temp\ipykernel_17268\992650362.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(median_value,inplace=True)
# C:\Users\leono\AppData\Local\Temp\ipykernel_17268\992650362.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(median_value,inplace=True)
# C:\Users\leono\AppData\Local\Temp\ipykernel_17268\992650362.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(median_value,inplace=True)
# C:\Users\leono\AppData\Local\Temp\ipykernel_17268\992650362.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(median_value,inplace=True)
# C:\Users\leono\AppData\Local\Temp\ipykernel_17268\992650362.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(median_value,inplace=True)
# C:\Users\leono\AppData\Local\Temp\ipykernel_17268\992650362.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(median_value,inplace=True)
# C:\Users\leono\AppData\Local\Temp\ipykernel_17268\992650362.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(median_value,inplace=True)
# C:\Users\leono\AppData\Local\Temp\ipykernel_17268\992650362.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(median_value,inplace=True)
# C:\Users\leono\AppData\Local\Temp\ipykernel_17268\992650362.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(median_value,inplace=True)
# C:\Users\leono\AppData\Local\Temp\ipykernel_17268\992650362.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(median_value,inplace=True)
# C:\Users\leono\AppData\Local\Temp\ipykernel_17268\992650362.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(median_value,inplace=True)
# C:\Users\leono\AppData\Local\Temp\ipykernel_17268\992650362.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(median_value,inplace=True)
# C:\Users\leono\AppData\Local\Temp\ipykernel_17268\992650362.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(median_value,inplace=True)
# C:\Users\leono\AppData\Local\Temp\ipykernel_17268\992650362.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(median_value,inplace=True)
# C:\Users\leono\AppData\Local\Temp\ipykernel_17268\992650362.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(median_value,inplace=True)
# C:\Users\leono\AppData\Local\Temp\ipykernel_17268\992650362.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(median_value,inplace=True)
# C:\Users\leono\AppData\Local\Temp\ipykernel_17268\992650362.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(mode_value,inplace=True)

# %%
hcc_data.isna().sum()
# Out:
# Gender            0
# Symptoms          0
# Alcohol           0
# HBsAg             0
# HBeAg             0
# HBcAb             0
# HCVAb             0
# Cirrhosis         0
# Endemic           0
# Smoking           0
# Diabetes          0
# Obesity           0
# Hemochro          0
# AHT               0
# CRI               0
# HIV               0
# NASH              0
# Varices           0
# Spleno            0
# PHT               0
# PVT               0
# Metastasis        0
# Hallmark          0
# Age               0
# Grams_day         0
# Packs_year        0
# PS                0
# Encephalopathy    0
# Ascites           0
# INR               0
# AFP               0
# Hemoglobin        0
# MCV               0
# Leucocytes        0
# Platelets         0
#  Albumin          0
# Total_Bil         0
# ALT               0
# AST               0
# GGT               0
# ALP               0
# TP                0
# Creatinine        0
# Nodules           0
# Major_Dim         0
# Dir_Bil           0
# Iron              0
# Sat               0
# Ferritin          0
# Class             0
# dtype: int64

# %% [markdown]
# ### 4.Data preparation <a id='data_preparation'></a>
#
# [Back_to_top](#table_of_contents)

# %%
data = hcc_data.copy() #deep copy

# %%
numerical_columns = ['Age','AFP', 'Hemoglobin', 'MCV','Nodules', 'Major_Dim', 'Dir_Bil', 'Iron',
                    ' Albumin','ALT','AST','GGT','ALP','Total_Bil','INR']
categorical_columns = ['Gender','Alcohol', 'HBsAg', 'HBeAg', 'HBcAb', 'HCVAb',
                    'Cirrhosis','Smoking', 'Diabetes', 'Obesity','PVT','Class']
all_needed_columns = categorical_columns + numerical_columns

# %%
main_data = data[all_needed_columns]
print(main_data.shape)
main_data.head()
# Out:
# (165, 27)
#    Gender Alcohol HBsAg HBeAg HBcAb HCVAb Cirrhosis Smoking Diabetes Obesity  \
# 0    Male     Yes    No    No    No    No       Yes     Yes      Yes      No
# 1  Female      No    No    No    No   Yes       Yes     Yes      Yes      No
# 2    Male     Yes   Yes    No   Yes    No       Yes     Yes       No      No
# 3    Male     Yes    No    No    No    No       Yes     Yes      Yes      No
# 4    Male     Yes   Yes    No   Yes    No       Yes     Yes       No      No
#
#   PVT  Class  Age     AFP  Hemoglobin     MCV  Nodules  Major_Dim  Dir_Bil  \
# 0  No  Lives   67    95.0        13.7  106.60      1.0        3.5      0.5
# 1  No  Lives   62    30.5        13.1   94.75      1.0        1.8      0.7
# 2  No  Lives   78     5.8         8.9   79.80      5.0       13.0      0.1
# 3  No   Dies   77  2440.0        13.4   97.10      2.0       15.7      0.2
# 4  No  Lives   76    49.0        14.3   95.10      1.0        9.0      0.7
#
#    Iron   Albumin    ALT    AST    GGT    ALP  Total_Bil    INR
# 0  83.0       3.4   34.0   41.0  183.0  150.0        2.1  1.530
# 1  83.0       3.4   50.0   70.0  178.0  159.5        1.3  1.285
# 2  28.0       3.3   58.0   68.0  202.0  109.0        0.4  0.960
# 3  83.0       3.7   16.0   64.0   94.0  174.0        0.4  0.950
# 4  59.0       4.1  147.0  306.0  173.0  109.0        0.7  0.940

# %%
data2 = main_data.groupby(categorical_columns).mean().reset_index()
data2['count'] = main_data.groupby(categorical_columns).size().reset_index(name='count')['count']
print(data2.shape)
data2.head(20)
# Out:
# (89, 28)
#     Gender Alcohol HBsAg HBeAg HBcAb HCVAb Cirrhosis Smoking Diabetes Obesity  \
# 0   Female      No    No    No    No    No        No      No       No      No
# 1   Female      No    No    No    No    No        No      No       No      No
# 2   Female      No    No    No    No    No        No      No       No      No
# 3   Female      No    No    No    No    No        No     Yes       No      No
# 4   Female      No    No    No    No    No       Yes      No       No      No
# 5   Female      No    No    No    No    No       Yes      No       No      No
# 6   Female      No    No    No    No    No       Yes      No       No      No
# 7   Female      No    No    No    No    No       Yes      No       No     Yes
# 8   Female      No    No    No    No    No       Yes      No      Yes      No
# 9   Female      No    No    No    No    No       Yes      No      Yes     Yes
# 10  Female      No    No    No    No   Yes        No      No      Yes      No
# 11  Female      No    No    No    No   Yes       Yes      No      Yes      No
# 12  Female      No    No    No    No   Yes       Yes     Yes      Yes      No
# 13  Female      No    No    No   Yes    No       Yes      No       No      No
# 14  Female      No    No    No   Yes    No       Yes     Yes       No      No
# 15  Female      No    No    No   Yes   Yes       Yes      No       No      No
# 16  Female     Yes    No    No    No    No       Yes      No       No      No
# 17  Female     Yes    No    No    No    No       Yes      No      Yes      No
# 18  Female     Yes    No    No    No    No       Yes     Yes       No      No
# 19  Female     Yes    No    No    No    No       Yes     Yes       No      No
#
#     PVT  Class        Age          AFP  Hemoglobin        MCV   Nodules  \
# 0    No   Dies  54.500000   428.500000       10.95  84.000000  5.000000
# 1    No  Lives  56.333333    17.733333       13.50  91.516667  1.333333
# 2   Yes  Lives  25.000000     1.500000       13.10  94.750000  1.000000
# 3    No  Lives  56.000000  2089.000000       15.40  91.600000  5.000000
# 4    No   Dies  54.000000  2445.050000       13.60  87.450000  3.000000
# 5    No  Lives  81.000000    16.000000       13.30  94.300000  1.000000
# 6   Yes   Dies  43.000000   180.000000       12.20  87.600000  5.000000
# 7   Yes  Lives  75.000000     4.200000       14.90  87.400000  5.000000
# 8    No  Lives  36.000000   615.000000       11.70  99.700000  5.000000
# 9    No  Lives  71.000000     2.600000       13.30  96.400000  5.000000
# 10   No   Dies  78.000000    77.000000       10.80  88.000000  3.000000
# 11   No   Dies  72.000000   152.000000       10.90  99.600000  2.000000
# 12   No  Lives  62.000000    30.500000       13.10  94.750000  1.000000
# 13   No  Lives  23.000000   358.000000       12.70  74.000000  2.000000
# 14   No  Lives  55.000000     4.900000       13.60  97.300000  2.000000
# 15   No  Lives  61.500000   128.000000       14.75  93.200000  3.500000
# 16  Yes  Lives  41.000000     4.600000       10.20  89.600000  2.000000
# 17   No   Dies  77.000000     2.000000       11.60  83.500000  2.000000
# 18   No   Dies  86.000000    30.500000       15.00  85.500000  5.000000
# 19   No  Lives  62.000000     6.600000       12.30  96.450000  3.666667
#
#     Major_Dim   Dir_Bil        Iron   Albumin        ALT         AST  \
# 0   10.475000  0.500000   48.500000      2.90  54.000000  143.500000
# 1    9.150000  0.506667   85.666667      3.60  35.000000   47.666667
# 2    6.600000  0.700000   83.000000      3.40  50.000000   70.000000
# 3    6.000000  0.600000   83.000000      4.40  45.000000   32.000000
# 4    5.000000  1.250000   64.500000      2.90  62.000000   70.500000
# 5    2.400000  0.300000   83.000000      3.80  26.000000   35.000000
# 6    9.000000  0.700000   83.000000      3.50  79.000000   58.000000
# 7   17.500000  0.300000   83.000000      3.50  31.000000   61.000000
# 8    1.900000  1.000000   83.000000      2.82  66.000000   50.000000
# 9    8.300000  0.700000   83.000000      4.10  70.000000   52.000000
# 10  15.400000  0.700000   83.000000      3.20  48.000000   19.000000
# 11   9.000000  0.700000   83.000000      3.20  82.000000   80.000000
# 12   1.800000  0.700000   83.000000      3.40  50.000000   70.000000
# 13   5.400000  0.800000   50.000000      2.90  53.000000   41.000000
# 14   3.320000  0.700000   78.000000      4.50  54.000000   63.000000
# 15   2.750000  0.400000  113.000000      3.80  86.000000   84.500000
# 16   2.600000  1.300000   25.000000      3.10  24.000000   57.000000
# 17   5.800000  0.700000   83.000000      3.89  23.000000   48.000000
# 18  15.800000  0.300000   21.000000      3.60  49.000000  117.000000
# 19   4.533333  1.633333   83.000000      3.30  37.333333   66.666667
#
#            GGT         ALP  Total_Bil       INR  count
# 0   415.000000  563.000000   0.550000  1.030000      2
# 1   113.333333  272.500000   0.806667  1.245000      3
# 2   178.000000  159.500000   1.300000  1.285000      1
# 3   717.000000  295.000000   1.300000  1.250000      1
# 4    85.000000  192.000000   2.450000  1.250000      2
# 5    75.000000  105.000000   1.200000  1.180000      1
# 6   229.000000  302.000000   0.500000  1.250000      1
# 7   196.000000  150.000000   0.600000  1.220000      1
# 8   120.000000  318.000000   3.000000  1.520000      1
# 9   141.000000  123.000000   0.600000  1.240000      1
# 10  171.000000  159.500000   0.900000  1.320000      1
# 11  427.000000  106.000000   1.300000  1.210000      1
# 12  178.000000  159.500000   1.300000  1.285000      1
# 13   54.000000   94.000000   2.800000  1.170000      1
# 14  487.000000   89.000000   0.900000  1.190000      1
# 15   97.500000  100.500000   1.500000  1.445000      2
# 16  163.000000  176.000000   3.100000  1.610000      1
# 17  319.000000  171.000000   0.900000  1.070000      1
# 18  442.000000  278.000000   1.000000  1.200000      1
# 19   93.333333  117.333333   3.666667  1.341667      3

# %% [markdown]
# ### 5. Benchmark model <a id='Benchmark_model'></a>
#
# [Back_to_top](#table_of_contents)

# %%
data3 = data2.copy() #data for benchmark model

# %%
categorical_features_benchmark = ['Gender','Alcohol', 'HBsAg', 'HBeAg', 'HBcAb', 'HCVAb',
                    'Cirrhosis','Smoking', 'Diabetes', 'Obesity','PVT']
input_features_benchmark = categorical_features_benchmark + numerical_columns
target_feature_benchmark = ['Class']

# %% [markdown]
# #### 5.1. Train-test split <a id='Train_test_split'></a>

# %%
from sklearn.model_selection import train_test_split

# %%
X_bench = data3[input_features_benchmark]
y_bench = data3[target_feature_benchmark]

# %%
#one-hot encode
X_bench = pd.get_dummies(X_bench)
y_bench = pd.get_dummies(y_bench)

# %%
X_train_b,X_test_b,y_train_b,y_test_b = train_test_split(X_bench,y_bench,test_size=0.30,random_state=42)
# 30%(50) sera o teste e 70%(115) sera o training

# %% [markdown]
# #### 5.2. Fit a model to the data <a id='Fit_a_model_to_the_data'></a>

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
tree = DecisionTreeClassifier(max_depth=10)
tree.fit(X_train_b,y_train_b)
# Out:
# DecisionTreeClassifier(max_depth=10)

# %% [markdown]
# #### 5.3. Model evaluation <a id='Model_evaluation'></a>

# %%
model = tree

# %%
y_pred_b = model.predict(X_test_b)

from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

print(classification_report(y_test_b,y_pred_b))
print("Accuracy:",accuracy_score(y_test_b,y_pred_b))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.55      0.52        11
#            1       0.67      0.62      0.65        16
#
#    micro avg       0.59      0.59      0.59        27
#    macro avg       0.58      0.59      0.58        27
# weighted avg       0.60      0.59      0.59        27
#  samples avg       0.59      0.59      0.59        27
#
# Accuracy: 0.5925925925925926

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'max_depth': [10, 15, 20],
    'min_samples_split': [2, 10, 20],
    'min_samples_leaf': [1, 5, 10]
}

grid_search = GridSearchCV(DecisionTreeClassifier(), param_grid, cv=5)
grid_search.fit(X_train_b, y_train_b)
print("Best parameters:", grid_search.best_params_)
print("Best cross-validation score: {:.2f}".format(grid_search.best_score_))
# Out:
# Best parameters: {'max_depth': 20, 'min_samples_leaf': 10, 'min_samples_split': 20}
# Best cross-validation score: 0.66

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# Calcular métricas de desempenho
accuracy = accuracy_score(y_test_b, y_pred_b)
precision = precision_score(y_test_b, y_pred_b, average='weighted')  # 'weighted' lida com desbalanceamento de classe
recall = recall_score(y_test_b, y_pred_b, average='weighted')
f1 = f1_score(y_test_b, y_pred_b, average='weighted')
# AUC-ROC (se as previsões são probabilísticas e a tarefa é binária ou se temos one-vs-rest para multiclasse)
# auc_roc = roc_auc_score(y_test_b, model.predict_proba(X_test_b), multi_class='ovr')

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# Out:
# Accuracy: 0.5925925925925926
# Precision: 0.5987654320987653
# Recall: 0.5925925925925926
# F1 Score: 0.5948781881460703

# %% [markdown]
# ### 6. Feature engineering <a id='Feature_engineering'></a>
#
# [Back_to_top](#table_of_contents)

# %% [markdown]
# ### 7. Model training <a id='Model_training'></a>
#
# [Back_to_top](#table_of_contents)

# %% [markdown]
# #####    7.1. Decision tree <a id='Decision_tree'></a>

# %% [markdown]
# ##### 7.2. KNN   <a id='KNN'></a>

# %% [markdown]
# ##### 7.3. Comparing Algorithm performance <a id='Comparing_algorithm_performance'></a>

# %% [markdown]
# ### 8. Tuning <a id='Tuning'></a>
# [Back_to_top](#table_of_contents)
