# %%
import pandas as pd
pd.set_option('display.max_columns',None)
#pd.set_option('display.max_rows',None)

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
import scipy

import sklearn
from sklearn.preprocessing import StandardScaler

# %%
hcc_data = pd.read_csv(r"C:\Users\catar\OneDrive\Ambiente de Trabalho\1 ano\s2\eiacd\projeto2_cd\hcc_dataset.csv")
hcc_data
# Out:
#      Gender Symptoms Alcohol HBsAg HBeAg HBcAb HCVAb Cirrhosis Endemic  \
# 0      Male       No     Yes    No    No    No    No       Yes      No
# 1    Female        ?      No    No    No    No   Yes       Yes       ?
# 2      Male       No     Yes   Yes    No   Yes    No       Yes      No
# 3      Male      Yes     Yes    No    No    No    No       Yes      No
# 4      Male      Yes     Yes   Yes    No   Yes    No       Yes      No
# ..      ...      ...     ...   ...   ...   ...   ...       ...     ...
# 160  Female       No     Yes     ?     ?     ?   Yes       Yes      No
# 161  Female      Yes      No     ?     ?     ?     ?       Yes      No
# 162    Male       No     Yes    No    No    No    No       Yes      No
# 163    Male       No     Yes   Yes    No   Yes   Yes       Yes     Yes
# 164    Male      Yes     Yes    No    No    No   Yes       Yes      No
#
#     Smoking Diabetes Obesity Hemochro  AHT  CRI  HIV NASH Varices Spleno  PHT  \
# ...

# %%
hcc_data.replace('?', np.nan, inplace=True)
hcc_data
# Out:
#      Gender Symptoms Alcohol HBsAg HBeAg HBcAb HCVAb Cirrhosis Endemic  \
# 0      Male       No     Yes    No    No    No    No       Yes      No
# 1    Female      NaN      No    No    No    No   Yes       Yes     NaN
# 2      Male       No     Yes   Yes    No   Yes    No       Yes      No
# 3      Male      Yes     Yes    No    No    No    No       Yes      No
# 4      Male      Yes     Yes   Yes    No   Yes    No       Yes      No
# ..      ...      ...     ...   ...   ...   ...   ...       ...     ...
# 160  Female       No     Yes   NaN   NaN   NaN   Yes       Yes      No
# 161  Female      Yes      No   NaN   NaN   NaN   NaN       Yes      No
# 162    Male       No     Yes    No    No    No    No       Yes      No
# 163    Male       No     Yes   Yes    No   Yes   Yes       Yes     Yes
# 164    Male      Yes     Yes    No    No    No   Yes       Yes      No
#
#     Smoking Diabetes Obesity Hemochro  AHT  CRI  HIV NASH Varices Spleno  PHT  \
# ...

# %%
hcc_data.dtypes
# Out:
# Gender            object
# Symptoms          object
# Alcohol           object
# HBsAg             object
# HBeAg             object
# HBcAb             object
# HCVAb             object
# Cirrhosis         object
# Endemic           object
# Smoking           object
# Diabetes          object
# Obesity           object
# Hemochro          object
# AHT               object
# CRI               object
# HIV               object
# NASH              object
# Varices           object
# Spleno            object
# PHT               object
# PVT               object
# Metastasis        object
# Hallmark          object
# Age                int64
# Grams_day         object
# Packs_year        object
# PS                object
# Encephalopathy    object
# Ascites           object
# INR               object
# AFP               object
# Hemoglobin        object
# MCV               object
# Leucocytes        object
# Platelets         object
# Albumin           object
# Total_Bil         object
# ...

# %%
hcc_data.isna().sum()
# Out:
# Gender              0
# Symptoms           18
# Alcohol             0
# HBsAg              17
# HBeAg              39
# HBcAb              24
# HCVAb               9
# Cirrhosis           0
# Endemic            39
# Smoking            41
# Diabetes            3
# Obesity            10
# Hemochro           23
# AHT                 3
# CRI                 2
# HIV                14
# NASH               22
# Varices            52
# Spleno             15
# PHT                11
# PVT                 3
# Metastasis          4
# Hallmark            2
# Age                 0
# Grams_day          48
# Packs_year         53
# PS                  0
# Encephalopathy    143
# Ascites           111
# INR                 4
# AFP                 8
# Hemoglobin          3
# MCV                 3
# Leucocytes          3
# Platelets           3
# Albumin             6
# Total_Bil           5
# ALT                 4
# AST                 3
# GGT                 3
# ALP                 3
# ...

# %%
hcc_data['Class']
# Out:
# 0      Lives
# 1      Lives
# 2      Lives
# 3       Dies
# 4      Lives
#        ...
# 160    Lives
# 161     Dies
# 162    Lives
# 163     Dies
# 164     Dies
# Name: Class, Length: 165, dtype: object

# %%
hcc_data['Class'].unique()
# Out:
# array(['Lives', 'Dies'], dtype=object)

# %%
hcc_data['Class'] = hcc_data['Class'].map({'Lives':1, 'Dies':0})
hcc_data['Class']
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      1
#       ..
# 160    1
# 161    0
# 162    1
# 163    0
# 164    0
# Name: Class, Length: 165, dtype: int64

# %%
hcc_data['Ascites'].unique()
# Out:
# array([nan, 'Mild', 'Moderate/Severe'], dtype=object)

# %%
hcc_data.columns
# Out:
# Index(['Gender', 'Symptoms', 'Alcohol', 'HBsAg', 'HBeAg', 'HBcAb', 'HCVAb',
#        'Cirrhosis', 'Endemic', 'Smoking', 'Diabetes', 'Obesity', 'Hemochro',
#        'AHT', 'CRI', 'HIV', 'NASH', 'Varices', 'Spleno', 'PHT', 'PVT',
#        'Metastasis', 'Hallmark', 'Age', 'Grams_day', 'Packs_year', 'PS',
#        'Encephalopathy', 'Ascites', 'INR', 'AFP', 'Hemoglobin', 'MCV',
#        'Leucocytes', 'Platelets', 'Albumin', 'Total_Bil', 'ALT', 'AST', 'GGT',
#        'ALP', 'TP', 'Creatinine', 'Nodules', 'Major_Dim', 'Dir_Bil', 'Iron',
#        'Sat', 'Ferritin', 'Class'],
#       dtype='object')

# %%
hcc_data_categ = hcc_data[['Gender','PS',
       'Encephalopathy', 'Ascites']]
hcc_data_yesorno = hcc_data[['Symptoms', 'Alcohol', 'HBsAg', 'HBeAg', 'HBcAb', 'HCVAb',
       'Cirrhosis', 'Endemic', 'Smoking', 'Diabetes', 'Obesity', 'Hemochro',
       'AHT', 'CRI', 'HIV', 'NASH', 'Varices', 'Spleno', 'PHT', 'PVT',
       'Metastasis', 'Hallmark']]
hcc_data_num = hcc_data[['Age', 'Grams_day', 'Packs_year','INR', 'AFP', 'Hemoglobin', 'MCV',
       'Leucocytes', 'Platelets', 'Albumin', 'Total_Bil', 'ALT', 'AST', 'GGT',
       'ALP', 'TP', 'Creatinine', 'Nodules', 'Major_Dim', 'Dir_Bil', 'Iron',
       'Sat', 'Ferritin']]
hcc_data_class = hcc_data[['Class']]

# %%
hcc_data_num['Packs_year'].hist(bins=60, figsize=(10,5))
# Out:
# <Axes: >

# %%
hcc_data_num = hcc_data_num.astype(float)

# %%
hcc_data_num.dtypes
# Out:
# Age           float64
# Grams_day     float64
# Packs_year    float64
# INR           float64
# AFP           float64
# Hemoglobin    float64
# MCV           float64
# Leucocytes    float64
# Platelets     float64
# Albumin       float64
# Total_Bil     float64
# ALT           float64
# AST           float64
# GGT           float64
# ALP           float64
# TP            float64
# Creatinine    float64
# Nodules       float64
# Major_Dim     float64
# Dir_Bil       float64
# Iron          float64
# Sat           float64
# Ferritin      float64
# dtype: object

# %%
hcc_data_num.plot(kind='hist', figsize=(10,5))
# Out:
# <Axes: ylabel='Frequency'>

# %%
hcc_data_num['Packs_year'].plot(kind='hist', bins=20, figsize=(10,5))
# Out:
# <Axes: ylabel='Frequency'>

# %%
hcc_data_num.hist(bins=20, figsize=(30,20))
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Grams_day'}>,
#         <Axes: title={'center': 'Packs_year'}>,
#         <Axes: title={'center': 'INR'}>, <Axes: title={'center': 'AFP'}>],
#        [<Axes: title={'center': 'Hemoglobin'}>,
#         <Axes: title={'center': 'MCV'}>,
#         <Axes: title={'center': 'Leucocytes'}>,
#         <Axes: title={'center': 'Platelets'}>,
#         <Axes: title={'center': 'Albumin'}>],
#        [<Axes: title={'center': 'Total_Bil'}>,
#         <Axes: title={'center': 'ALT'}>, <Axes: title={'center': 'AST'}>,
#         <Axes: title={'center': 'GGT'}>, <Axes: title={'center': 'ALP'}>],
#        [<Axes: title={'center': 'TP'}>,
#         <Axes: title={'center': 'Creatinine'}>,
#         <Axes: title={'center': 'Nodules'}>,
#         <Axes: title={'center': 'Major_Dim'}>,
#         <Axes: title={'center': 'Dir_Bil'}>],
#        [<Axes: title={'center': 'Iron'}>,
#         <Axes: title={'center': 'Sat'}>,
# ...

# %%
lotpacks_year = hcc_data[hcc_data_num['Packs_year']>100]
lotpacks_year
# Out:
#     Gender Symptoms Alcohol HBsAg HBeAg HBcAb HCVAb Cirrhosis Endemic Smoking  \
# 128   Male       No      No   Yes    No    No    No       Yes      No     Yes
#
#     Diabetes Obesity Hemochro AHT CRI HIV NASH Varices Spleno PHT PVT  \
# 128       No      No       No  No  No  No   No     NaN    NaN  No  No
#
#     Metastasis Hallmark  Age Grams_day Packs_year          PS Encephalopathy  \
# 128         No       No   72         0        510  Ambulatory            NaN
#
#     Ascites   INR  AFP Hemoglobin   MCV Leucocytes Platelets Albumin  \
# 128     NaN  1.13  2.1       12.6  95.1        8.7    254000    3.68
#
#     Total_Bil ALT AST  GGT  ALP   TP Creatinine Nodules Major_Dim Dir_Bil  \
# 128       0.7  26  38  161  127  6.9       1.11       2       4.3     NaN
#
#     Iron Sat Ferritin  Class
# 128   28  10      308      0

# %%
hcc_data_num.boxplot(column = 'Packs_year', figsize=(20,10))
# Out:
# <Axes: >

# %%
hcc_data_num.boxplot(column = 'Grams_day', figsize=(20,10))
# Out:
# <Axes: >

# %%
hcc_data_num.boxplot(column = 'INR', figsize=(20,10))
# Out:
# <Axes: >

# %%
hcc_data_num.boxplot(column = 'AFP', figsize=(20,10))
# Out:
# <Axes: >

# %%
hcc_data_num.boxplot(column = 'Leucocytes', figsize=(20,10))
# Out:
# <Axes: >

# %%
hcc_data_num.boxplot(column = 'Total_Bil', figsize=(20,10))
# Out:
# <Axes: >

# %%
hcc_data_num['INR'].plot(figsize=(20,10))
# Out:
# <Axes: >

# %%
hcc_data_num['Creatinine'].plot(figsize=(20,10))
# Out:
# <Axes: >
