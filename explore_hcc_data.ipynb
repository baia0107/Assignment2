# %%
import pandas as pd
pd.set_option('display.max_columns',None)
#pd.set_option('display.max_rows',None)

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
import scipy

import sklearn
from sklearn.preprocessing import StandardScaler

# %%
hcc_data = pd.read_csv(r"C:\Users\catar\OneDrive\Ambiente de Trabalho\1 ano\s2\eiacd\projeto2_cd\hcc_dataset.csv")
hcc_data
# Out:
#      Gender Symptoms Alcohol HBsAg HBeAg HBcAb HCVAb Cirrhosis Endemic  \
# 0      Male       No     Yes    No    No    No    No       Yes      No
# 1    Female        ?      No    No    No    No   Yes       Yes       ?
# 2      Male       No     Yes   Yes    No   Yes    No       Yes      No
# 3      Male      Yes     Yes    No    No    No    No       Yes      No
# 4      Male      Yes     Yes   Yes    No   Yes    No       Yes      No
# ..      ...      ...     ...   ...   ...   ...   ...       ...     ...
# 160  Female       No     Yes     ?     ?     ?   Yes       Yes      No
# 161  Female      Yes      No     ?     ?     ?     ?       Yes      No
# 162    Male       No     Yes    No    No    No    No       Yes      No
# 163    Male       No     Yes   Yes    No   Yes   Yes       Yes     Yes
# 164    Male      Yes     Yes    No    No    No   Yes       Yes      No
#
#     Smoking Diabetes Obesity Hemochro  AHT  CRI  HIV NASH Varices Spleno  PHT  \
# ...

# %%
hcc_data.replace('?', np.nan, inplace=True)
hcc_data

# %%
hcc_data.columns

# %%
hcc_datanumerical_cols = hcc_data[['Grams_day', 'Packs_year', 'INR', 'AFP', 'Hemoglobin', 'MCV', 'Leucocytes', 'Platelets',
                  'Albumin', 'Total_Bil', 'ALT', 'AST', 'GGT', 'ALP', 'TP', 'Creatinine', 'Nodules', 'Major_Dim',
                  'Dir_Bil', 'Iron', 'Sat', 'Ferritin','Class']]
hcc_datanumerical_cols

# %%
hcc_data.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 hcc_data.isna().sum()
#
# NameError: name 'hcc_data' is not defined

# %%
hcc_data_subset.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 hcc_data_subset.isna().sum()
#
# NameError: name 'hcc_data_subset' is not defined

# %%
hcc_data.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 hcc_data.describe()
#
# NameError: name 'hcc_data' is not defined

# %%
hcc_data.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 hcc_data.dtypes
#
# NameError: name 'hcc_data' is not defined

# %%
# Converter cada coluna para numérico, tratando erros
for col in hcc_datanumerical_cols:
    # Verificar se a coluna é de tipo object, indicando possível presença de strings
    if hcc_datanumerical_cols[col].dtype == 'object':
        hcc_datanumerical_cols[col] = pd.to_numeric(hcc_datanumerical_cols[col].str.replace(' ', ''), errors='coerce')
    else:
        # Se não for object, converte diretamente
        hcc_datanumerical_cols[col] = pd.to_numeric(hcc_datanumerical_cols[col], errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Converter cada coluna para numérico, tratando erros
# ----> 2 for col in hcc_datanumerical_cols:
#       3     # Verificar se a coluna é de tipo object, indicando possível presença de strings
#       4     if hcc_datanumerical_cols[col].dtype == 'object':
#       5         hcc_datanumerical_cols[col] = pd.to_numeric(hcc_datanumerical_cols[col].str.replace(' ', ''), errors='coerce')
#
# NameError: name 'hcc_datanumerical_cols' is not defined

# %%
hcc_datanumerical_cols
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 hcc_datanumerical_cols
#
# NameError: name 'hcc_datanumerical_cols' is not defined

# %%
hcc_datanumerical_cols.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 hcc_datanumerical_cols.dtypes
#
# NameError: name 'hcc_datanumerical_cols' is not defined
